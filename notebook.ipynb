# %%
import pymongo

# %%
print("OK")
# Out:
# OK

# %%
'mongodb+srv://silritzzz:Yp2WCfGNqa25Nx5E@us-visa-approval-cluste.lx4st98.mongodb.net/?retryWrites=true&w=majority&appName=us-visa-approval-cluster-1'

# %%
filepath ='C:\\Users\\silri\\Applied_AI\\00_Machine_Learning_Projects\\MLOPs-Project\\US-Visa-Approval-Prediction\\US-Visa-Application-Prediction\\data\\Visadataset.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(filepath)
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = 'US_Visa'
COLLECTION_NAME = 'visa_data'
CONNECTION_URL  = 'mongodb+srv://silritzzz:Yp2WCfGNqa25Nx5E@us-visa-approval-cluste.lx4st98.mongodb.net/?retryWrites=true&w=majority&appName=us-visa-approval-cluster-1'

# %%
import pymongo
import certifi

ca = certifi.where()

# %%
client = pymongo.MongoClient(CONNECTION_URL)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('65fed74251e081ba6bcd28c9'), ObjectId('65fed74251e081ba6bcd28ca'), ObjectId('65fed74251e081ba6bcd28cb'), ObjectId('65fed74251e081ba6bcd28cc'), ObjectId('65fed74251e081ba6bcd28cd'), ObjectId('65fed74251e081ba6bcd28ce'), ObjectId('65fed74251e081ba6bcd28cf'), ObjectId('65fed74251e081ba6bcd28d0'), ObjectId('65fed74251e081ba6bcd28d1'), ObjectId('65fed74251e081ba6bcd28d2'), ObjectId('65fed74251e081ba6bcd28d3'), ObjectId('65fed74251e081ba6bcd28d4'), ObjectId('65fed74251e081ba6bcd28d5'), ObjectId('65fed74251e081ba6bcd28d6'), ObjectId('65fed74251e081ba6bcd28d7'), ObjectId('65fed74251e081ba6bcd28d8'), ObjectId('65fed74251e081ba6bcd28d9'), ObjectId('65fed74251e081ba6bcd28da'), ObjectId('65fed74251e081ba6bcd28db'), ObjectId('65fed74251e081ba6bcd28dc'), ObjectId('65fed74251e081ba6bcd28dd'), ObjectId('65fed74251e081ba6bcd28de'), ObjectId('65fed74251e081ba6bcd28df'), ObjectId('65fed74251e081ba6bcd28e0'), ObjectId('65fed74251e081ba6bcd28e1'), ObjectId('65fed74251e081ba6bcd
# ...
